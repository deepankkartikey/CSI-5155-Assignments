# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_roc_curve 

LABELS = ['False', 'True']

# %% [markdown]
# # Importing Data from file

# %%
# read data from csv file
# dataset_url = https://archive.ics.uci.edu/ml/machine-learning-databases/00468/online_shoppers_intention.csv
shopper_intention_filename = 'online_shoppers_intention.csv'
shopper_intention_data = pd.read_csv(shopper_intention_filename)

# %%
shopper_intention_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  bool
#  17  Revenue                  12330 non-null  bool
# dtypes: bool(2), float64(7), int64(7), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Train-Test-Split

# %%
from sklearn.model_selection import train_test_split
feature_cols = [c for c in shopper_intention_data.columns if c not in ['Revenue']]
X = shopper_intention_data.loc[:,feature_cols]
y = shopper_intention_data.loc[:,["Revenue"]]

#X = shopper_intention.drop("Revenue", axis = 1)
#y = shopper_intention["Revenue"]

# seggregate dataset into Training(70%) and Validation(30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# feature_cols
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8631, 17), (3699, 17), (8631, 1), (3699, 1))

# %% [markdown]
# # 1. Feature Engineering
# ### 1.1 Find Highly correlated features and remove

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(20,20))
cor = X_train.corr(method='pearson')
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with any other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.55)  # selecting features having correlation > 80% (absolute)
len(set(corr_features))
# Out:
# 4

# %%
print("Highly Correlated Features: {}".format(corr_features))
# Out:
# Highly Correlated Features: {'Informational_Duration', 'Administrative_Duration', 'ExitRates', 'ProductRelated_Duration'}

# %%
X_train
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 6344                1                23.200000              0
# 4284                1                11.000000              0
# 3646                3               119.000000              1
# 11609               2               255.000000              0
# 12242               6               243.750000              0
# ...               ...                      ...            ...
# 3560                0                 0.000000              0
# 1234                0                 0.000000              0
# 6768                0                 0.000000              0
# 10036               4                19.666667              3
# 11889               0                 0.000000              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 6344                 0.000000               3               397.800000
# 4284                 0.000000              20               285.666667
# 3646                86.000000              25               413.722222
# 11609                0.000000              10               173.433333
# 12242                0.000000               8               171.250000
# ...                       ...             ...                      ...
# 3560                 0.000000              13               252.000000
# 1234                 0.000000              26               648.400000
# 6768                 0.000000               9               372.600000
# 10036              254.916667             147              4254.666667
# 11889                0.000000               4               137.500000
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 6344      0.000000   0.000000    0.000000         0.0   Aug                 2
# 4284      0.000000   0.022222    0.000000         0.0   May                 2
# 3646      0.000000   0.013077   15.400423         0.0   May                 1
# 11609     0.030000   0.025714    0.000000         0.0   Dec                 3
# 12242     0.038889   0.067222    0.000000         0.0   Dec                 3
# ...            ...        ...         ...         ...   ...               ...
# 3560      0.000000   0.061538    0.000000         0.0   May                 2
# 1234      0.000000   0.018000    0.000000         0.0   Mar                 1
# 6768      0.000000   0.022222   55.899789         0.0   Jul                 2
# 10036     0.008446   0.019250    0.000000         0.0   Nov                 2
# 11889     0.000000   0.066667    0.000000         0.0   Nov                 2
#
#        Browser  Region  TrafficType        VisitorType  Weekend
# 6344         2       1            4  Returning_Visitor    False
# 4284        10       3            3  Returning_Visitor    False
# 3646         1       7            4  Returning_Visitor    False
# 11609        2       1            1  Returning_Visitor     True
# 12242        2       3            1  Returning_Visitor    False
# ...        ...     ...          ...                ...      ...
# 3560         2       8            3  Returning_Visitor    False
# 1234         1       1            3  Returning_Visitor     True
# 6768         2       1            4  Returning_Visitor    False
# 10036        2       1            1  Returning_Visitor    False
# 11889        2       2           11  Returning_Visitor    False
#
# [8631 rows x 17 columns]

# %%
# Drop correlated features
X_train = X_train.drop(corr_features,axis=1)
X_test = X_test.drop(corr_features,axis=1)
# X_test.drop(corr_features,axis=1)
X_train.shape
# Out:
# (8631, 13)

# %%
X_train.head()
# Out:
#        Administrative  Informational  ProductRelated  BounceRates  PageValues  \
# 6344                1              0               3     0.000000    0.000000
# 4284                1              0              20     0.000000    0.000000
# 3646                3              1              25     0.000000   15.400423
# 11609               2              0              10     0.030000    0.000000
# 12242               6              0               8     0.038889    0.000000
#
#        SpecialDay Month  OperatingSystems  Browser  Region  TrafficType  \
# 6344          0.0   Aug                 2        2       1            4
# 4284          0.0   May                 2       10       3            3
# 3646          0.0   May                 1        1       7            4
# 11609         0.0   Dec                 3        2       1            1
# 12242         0.0   Dec                 3        2       3            1
#
#              VisitorType  Weekend
# 6344   Returning_Visitor    False
# 4284   Returning_Visitor    False
# 3646   Returning_Visitor    False
# 11609  Returning_Visitor     True
# 12242  Returning_Visitor    False

# %%
X_test.head()
# Out:
#       Administrative  Informational  ProductRelated  BounceRates  PageValues  \
# 7630               1              0               7     0.000000    0.000000
# 9019               8              4             118     0.004098   55.011313
# 1300               0              0              20     0.020000    0.000000
# 3596               4              0              21     0.000000    0.000000
# 9182               0              2             144     0.005517    0.000000
#
#       SpecialDay Month  OperatingSystems  Browser  Region  TrafficType  \
# 7630         0.0   Jul                 1        1       1            1
# 9019         0.0   Nov                 2        2       1            2
# 1300         0.0   Mar                 2        2       1            1
# 3596         0.0   May                 2        2       1            2
# 9182         0.0   Nov                 2        2       1           13
#
#             VisitorType  Weekend
# 7630  Returning_Visitor    False
# 9019  Returning_Visitor    False
# 1300  Returning_Visitor    False
# 3596  Returning_Visitor     True
# 9182  Returning_Visitor    False

# %% [markdown]
# ### 1.2 Scaling Numerical Features

# %%
scaled_features = X_train.copy()
scaled_test_features = X_test.copy()

col_names = ['Administrative','Informational','ProductRelated','BounceRates','PageValues','SpecialDay','OperatingSystems','Browser','Region','TrafficType']
features = scaled_features[col_names]
features_test = scaled_test_features[col_names]

scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
features_test = scaler.transform(features_test.values)

scaled_features[col_names] = features
scaled_features

scaled_test_features[col_names] = features_test
scaled_test_features
# Out:
#       Administrative  Informational  ProductRelated  BounceRates  PageValues  \
# 7630       -0.392711      -0.393768       -0.561627    -0.455630   -0.326078
# 9019        1.737129       2.709988        1.980631    -0.369987    2.760447
# 1300       -0.696974      -0.393768       -0.263885    -0.037693   -0.326078
# 3596        0.520078      -0.393768       -0.240981    -0.455630   -0.326078
# 9182       -0.696974       1.158110        2.576115    -0.340337   -0.326078
# ...              ...            ...             ...          ...         ...
# 6379        0.520078       0.382171        0.972889    -0.399905   -0.326078
# 5496       -0.696974      -0.393768       -0.355498    -0.455630    2.735520
# 7469        0.520078      -0.393768       -0.011949     0.066791   -0.326078
# 3594       -0.088448      -0.393768       -0.286788    -0.455630    0.796238
# 9380       -0.696974      -0.393768       -0.470014    -0.455630   -0.326078
#
#       SpecialDay Month  OperatingSystems   Browser    Region  TrafficType  \
# 7630   -0.306515   Jul         -1.209723 -0.785495 -0.888569    -0.754903
# 9019   -0.306515   Nov         -0.145497 -0.209977 -0.888569    -0.510205
# 1300   -0.306515   Mar         -0.145497 -0.209977 -0.888569    -0.754903
# 3596   -0.306515   May         -0.145497 -0.209977 -0.888569    -0.510205
# 9182   -0.306515   Nov         -0.145497 -0.209977 -0.888569     2.181470
# ...          ...   ...               ...       ...       ...          ...
# 6379   -0.306515   Aug         -0.145497 -0.209977 -0.054729    -0.754903
# 5496   -0.306515   Sep          1.982955 -0.785495 -0.888569    -0.020810
# 7469   -0.306515   Nov          0.918729 -0.209977  2.029868    -0.265507
# 3594   -0.306515   May         -0.145497 -0.209977 -0.888569    -0.510205
# 9380   -0.306515   Nov          0.918729 -0.209977  0.779110    -0.510205
#
#             VisitorType  Weekend
# 7630  Returning_Visitor    False
# 9019  Returning_Visitor    False
# 1300  Returning_Visitor    False
# 3596  Returning_Visitor     True
# 9182  Returning_Visitor    False
# ...                 ...      ...
# 6379  Returning_Visitor     True
# 5496        New_Visitor    False
# 7469  Returning_Visitor    False
# 3594  Returning_Visitor    False
# 9380        New_Visitor    False
#
# [3699 rows x 13 columns]

# %% [markdown]
# ### 1.3 Transform Categorical Features

# %%
# One-Hot Encoding VisitorType Feature
non_categoricals = ['Administrative','Informational','ProductRelated','BounceRates','PageValues','SpecialDay','Month','OperatingSystems','Browser','Region','TrafficType']
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
transformer = ColumnTransformer(transformers=[
    ('tnf1', OrdinalEncoder(categories=[months]),['Month']),
    ('tnf2', OneHotEncoder(drop='first', sparse=False),['VisitorType']),
], remainder='passthrough')
X_train = transformer.fit_transform(scaled_features)
X_test = transformer.transform(scaled_test_features)

# %% [markdown]
# # 2. Constructing and training model
# ### 2.1 Decision Tree

# %%
# Decision Tree 
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_leaf_nodes=8, class_weight='balanced')
# dtc = DecisionTreeClassifier()
# class weight has to be provided as number of positives and negatives is not equal.
dtc.fit(X_train, y_train)
y_train.shape
# Out:
# (8631, 1)

# %%
# # visualize decision tree
# from sklearn.tree import plot_tree

# plt.figure(figsize=(20,10))
# plot_tree(dtc, 
#           feature_names = feature_cols,
#           class_names = ['True', 'False'],
#           rounded = True,
#           filled = True)
# plt.show()

# %%
X_train.shape
# Out:
# (8631, 14)

# %%
# Predictions from Decision tree
y_train_predict_dtc = dtc.predict(X_train)
y_test_predict_dtc = dtc.predict(X_test)

# %%
X_test.shape
# Out:
# (3699, 14)

# %% [markdown]
# ### 2.2 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=50)
# rfc = RandomForestClassifier()

rfc.fit(X_train, y_train.values.ravel()) 

# Predictions from Random Forest Learner
y_train_predict_rfc = rfc.predict(X_train)
y_test_predict_rfc = rfc.predict(X_test)

# %% [markdown]
# ### 2.3 Support Vector Machine

# %%
from sklearn.svm import SVC

svm = SVC(C=100)
# svm = SVC()
svm.fit(X_train, y_train.values.ravel())

# Predictions from SVM
y_train_predict_svm = svm.predict(X_train)
y_test_predict_svm = svm.predict(X_test)

# %% [markdown]
# ### 2.4 K Nearest Neighbour

# %%
# K nearest neighbour classification
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=8)
# knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

y_test_predict_knn = knn.predict(X_test)
# Out:
# /Users/deepankkartikey/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# # 3. Confusion Matrices (Imbalanced Dataset)
# ### 3.1 Decision tree

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm_dtc = confusion_matrix(y_test, y_test_predict_dtc)

"""
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(5,5))
sn.heatmap(cm_dtc, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
"""

print(cm_dtc)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_dtc), 2))
print("\n Accuracy: ", round(accuracy_score(y_test, y_test_predict_dtc), 2))
# Out:
# [[2633  490]
#  [  87  489]]
#
#  F1- Score:  0.63
#
#  Accuracy:  0.84

# %% [markdown]
# ### 3.2 Random Forest Learner

# %%
cm_rfc = confusion_matrix(y_test, y_test_predict_rfc)

print(cm_rfc)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_rfc), 2))
print("\n Accuracy: ", round(accuracy_score(y_test, y_test_predict_rfc), 2))
# Out:
# [[2994  129]
#  [ 254  322]]
#
#  F1- Score:  0.63
#
#  Accuracy:  0.9

# %% [markdown]
# ### 3.3 Support Vector Machine

# %%
cm_svm = confusion_matrix(y_test, y_test_predict_svm)

print(cm_svm)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_svm), 2))
print("\n Accuracy: ", round(accuracy_score(y_test, y_test_predict_svm), 2))
# Out:
# [[3002  121]
#  [ 274  302]]
#
#  F1- Score:  0.6
#
#  Accuracy:  0.89

# %% [markdown]
# ### 3.4 K Nearest Neighbours

# %%
cm_knn = confusion_matrix(y_test, y_test_predict_knn)

print(cm_knn)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_knn), 2))
print("\n Accuracy: ", round(accuracy_score(y_test, y_test_predict_knn), 2))
# Out:
# [[3052   71]
#  [ 381  195]]
#
#  F1- Score:  0.46
#
#  Accuracy:  0.88

# %% [markdown]
# # 4. Plotting ROC curves

# %%
canvas = plot_roc_curve(dtc, X_test, y_test)
plot_roc_curve(rfc, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(svm, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(knn, X_test, y_test, ax=canvas.ax_);

# %% [markdown]
# ##### Various metric scores for Decision Tree

# %%
print(classification_report(y_test, y_test_predict_dtc))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.84      0.90      3123
#         True       0.50      0.85      0.63       576
#
#     accuracy                           0.84      3699
#    macro avg       0.73      0.85      0.77      3699
# weighted avg       0.90      0.84      0.86      3699

# %% [markdown]
# ##### Various metric scores for Random Forest Learner

# %%
print(classification_report(y_test, y_test_predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.96      0.94      3123
#         True       0.71      0.56      0.63       576
#
#     accuracy                           0.90      3699
#    macro avg       0.82      0.76      0.78      3699
# weighted avg       0.89      0.90      0.89      3699

# %% [markdown]
# ###### Metric scores for Support Vector machine

# %%
print(classification_report(y_test, y_test_predict_svm))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.96      0.94      3123
#         True       0.71      0.52      0.60       576
#
#     accuracy                           0.89      3699
#    macro avg       0.82      0.74      0.77      3699
# weighted avg       0.88      0.89      0.89      3699

# %% [markdown]
# ###### Metric scores for KNN

# %%
print(classification_report(y_test, y_test_predict_knn))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      0.98      0.93      3123
#         True       0.73      0.34      0.46       576
#
#     accuracy                           0.88      3699
#    macro avg       0.81      0.66      0.70      3699
# weighted avg       0.86      0.88      0.86      3699

# %% [markdown]
# # 5. Handling Imbalanced Dataset

# %%
# count classes to determine minority and majority
count_classes = pd.value_counts(shopper_intention_data['Revenue'], sort = True)
revenue_true = shopper_intention_data[shopper_intention_data['Revenue'] == True]
revenue_false = shopper_intention_data[shopper_intention_data['Revenue'] == False]
print('Revenue-True: {}\nRevenue-False: {}'.format(revenue_true.shape , revenue_false.shape))
count_classes.plot(kind = 'bar')
plt.title("Target Class Distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Revenue")
plt.ylabel("Frequency")
# Out:
# Revenue-True: (1908, 18)
# Revenue-False: (10422, 18)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 5.1 Oversampling Minority class in Training data

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

os =  RandomOverSampler()
X_train_os, y_train_os = os.fit_resample(X_train, y_train)

print("Class Distribution Before Oversampling: \n", y.value_counts(),"\n")
print("Class Distribution After Oversampling: \n", y_os.value_counts())
# Out:
# Class Distribution Before Oversampling:
#  Revenue
# False      10422
# True        1908
# dtype: int64
#
# Class Distribution After Oversampling:
#  Revenue
# False      7307
# True       7307
# dtype: int64

# %% [markdown]
# ### 5.1.1 Decision Tree

# %%
# Decision tree for over-sampled data
dtc_os = DecisionTreeClassifier(max_leaf_nodes=8, class_weight='balanced')
dtc_os.fit(X_train_os, y_train_os)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_leaf_nodes=8)

# %%
# visualize decision tree
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dtc_os, 
          feature_names = feature_cols,
          class_names = ['True', 'False'],
          rounded = True,
          filled = True)
plt.show()

# %%
# Predictions from Decision tree
y_train_predict_dtc = dtc_os.predict(X_train_os)
y_test_predict_dtc_os = dtc_os.predict(X_test)

# %%
# Plot Confusion Matrix for Decision Tree Classifier
from sklearn.metrics import confusion_matrix, classification_report
cm_dtc_os = confusion_matrix(y_test, y_test_predict_dtc_os)
""" 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
"""
print(cm_dtc_os)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_dtc_os), 3))

# Various metric scores for Decision Tree
print(classification_report(y_test, y_test_predict_dtc_os))
# Out:
# [[2657  466]
#  [  87  489]]
#
#  F1- Score:  0.639
#               precision    recall  f1-score   support
#
#        False       0.97      0.85      0.91      3123
#         True       0.51      0.85      0.64       576
#
#     accuracy                           0.85      3699
#    macro avg       0.74      0.85      0.77      3699
# weighted avg       0.90      0.85      0.86      3699

# %% [markdown]
# ### 5.1.2 Random Forest Learner

# %%
from sklearn.ensemble import RandomForestClassifier

rfc_os = RandomForestClassifier(n_estimators=50)
rfc_os.fit(X_train_os, y_train_os.values.ravel()) # 

# Predictions from Random Forest Learner
y_train_predict_rfc_os = rfc_os.predict(X_train_os)
y_test_predict_rfc_os = rfc_os.predict(X_test)

# %%
# Confusion Matrix for Random Forest Learner (Oversampled)
cm_rfc_os = confusion_matrix(y_test, y_test_predict_rfc_os)
print(cm_rfc_os)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_rfc_os), 3),"\n")

# Various metric scores for Random Forest Learner 
print(classification_report(y_test, y_test_predict_rfc_os))
# Out:
# [[2934  189]
#  [ 202  374]]
#
#  F1- Score:  0.657
#
#               precision    recall  f1-score   support
#
#        False       0.94      0.94      0.94      3123
#         True       0.66      0.65      0.66       576
#
#     accuracy                           0.89      3699
#    macro avg       0.80      0.79      0.80      3699
# weighted avg       0.89      0.89      0.89      3699

# %% [markdown]
# ### 5.1.3 Support Vector machine

# %%
from sklearn.svm import SVC

svm_os = SVC(C=100)
svm_os.fit(X_train_os, y_train_os.values.ravel())

# Predictions from SVM
y_train_predict_svm_os = svm_os.predict(X_train_os)
y_test_predict_svm_os = svm_os.predict(X_test)

# %%
cm_svm_os = confusion_matrix(y_test, y_test_predict_svm_os)

print(cm_svm_os)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_svm_os), 2))

# Various metric scores for SVM
print(classification_report(y_test, y_test_predict_svm_os))
# Out:
# [[2772  351]
#  [ 148  428]]
#
#  F1- Score:  0.63
#               precision    recall  f1-score   support
#
#        False       0.95      0.89      0.92      3123
#         True       0.55      0.74      0.63       576
#
#     accuracy                           0.87      3699
#    macro avg       0.75      0.82      0.77      3699
# weighted avg       0.89      0.87      0.87      3699

# %% [markdown]
# ### 5.1.4 K-Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_os = KNeighborsClassifier(n_neighbors=44)
knn_os.fit(X_train_os, y_train_os.values.ravel())

y_test_predict_knn_os = knn.predict(X_test)

## Confusion Matrix
cm_knn_os = confusion_matrix(y_test, y_test_predict_knn_os)
print(cm_knn_os)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_knn_os), 2))

# Various metric scores for KNN
print(classification_report(y_test, y_test_predict_knn_os))
# Out:
# [[3052   71]
#  [ 381  195]]
#
#  F1- Score:  0.46
#               precision    recall  f1-score   support
#
#        False       0.89      0.98      0.93      3123
#         True       0.73      0.34      0.46       576
#
#     accuracy                           0.88      3699
#    macro avg       0.81      0.66      0.70      3699
# weighted avg       0.86      0.88      0.86      3699

# %% [markdown]
# ### 5.1.5 Plotting ROC curves for Oversampled minority class

# %%
canvas = plot_roc_curve(dtc_os, X_test, y_test)
plot_roc_curve(rfc_os, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(svm_os, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(knn_os, X_test, y_test, ax=canvas.ax_);

# %% [markdown]
# ### 5.2 Undersampling Majority class in Training data

# %%
from imblearn.under_sampling import NearMiss

nm = NearMiss()
X_train_us,y_train_us=nm.fit_resample(X_train,y_train)

print("Class Distribution Before Oversampling: \n", y.value_counts(),"\n")
print("Class Distribution After Oversampling: \n", y_us.value_counts())
# Out:
# Class Distribution Before Oversampling:
#  Revenue
# False      10422
# True        1908
# dtype: int64
#
# Class Distribution After Oversampling:
#  Revenue
# False      1324
# True       1324
# dtype: int64

# %% [markdown]
# ### 5.2.1 Decision Tree

# %%
# Decision tree for over-sampled data
dtc_us = DecisionTreeClassifier(max_leaf_nodes=8, class_weight='balanced')
dtc_us.fit(X_train_us, y_train_us)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_leaf_nodes=8)

# %%
# visualize decision tree
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(dtc_us, 
          feature_names = feature_cols,
          class_names = ['True', 'False'],
          rounded = True,
          filled = True)
plt.show()

# %%
# Predictions from Decision tree
y_train_predict_dtc = dtc_us.predict(X_train_us)
y_test_predict_dtc_us = dtc_us.predict(X_test)

# %%
# Plot Confusion Matrix for Decision Tree Classifier
from sklearn.metrics import confusion_matrix, classification_report
cm_dtc_us = confusion_matrix(y_test, y_test_predict_dtc_us)
""" 
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
"""
print(cm_dtc_us)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_dtc_us), 3),"\n")

# Various metric scores for Decision Tree Classifier 
print(classification_report(y_test, y_test_predict_dtc_us))
# Out:
# [[2513  610]
#  [  88  488]]
#
#  F1- Score:  0.583
#
#               precision    recall  f1-score   support
#
#        False       0.97      0.80      0.88      3123
#         True       0.44      0.85      0.58       576
#
#     accuracy                           0.81      3699
#    macro avg       0.71      0.83      0.73      3699
# weighted avg       0.88      0.81      0.83      3699

# %% [markdown]
# ### 5.2.2 Random Forest Learner

# %%
from sklearn.ensemble import RandomForestClassifier

rfc_us = RandomForestClassifier(n_estimators=50)
rfc_us.fit(X_train_us, y_train_us.values.ravel()) # 

# Predictions from Random Forest Learner
y_train_predict_rfc_us = rfc_us.predict(X_train_us)
y_test_predict_rfc_us = rfc_us.predict(X_test)

# %%
# Confusion Matrix for Random Forest Learner (Oversampled)
cm_rfc_us = confusion_matrix(y_test, y_test_predict_rfc_us)
print(cm_rfc_us)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_rfc_us), 3),"\n")

# Various metric scores for Random Forest Learner 
print(classification_report(y_test, y_test_predict_rfc_us))
# Out:
# [[2096 1027]
#  [  64  512]]
#
#  F1- Score:  0.484
#
#               precision    recall  f1-score   support
#
#        False       0.97      0.67      0.79      3123
#         True       0.33      0.89      0.48       576
#
#     accuracy                           0.71      3699
#    macro avg       0.65      0.78      0.64      3699
# weighted avg       0.87      0.71      0.75      3699

# %% [markdown]
# ### 5.2.3 Support Vector Machines

# %%
from sklearn.svm import SVC

svm_us = SVC(C=100)
svm_us.fit(X_train_us, y_train_us.values.ravel())

# Predictions from SVM
y_train_predict_svm_us = svm_us.predict(X_train_us)
y_test_predict_svm_us = svm_us.predict(X_test)

# %%
cm_svm_us = confusion_matrix(y_test, y_test_predict_svm_us)

print(cm_svm_us)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_svm_us), 2), "\n")

# Various metric scores for SVM
print(classification_report(y_test, y_test_predict_svm_us))
# Out:
# [[1671 1452]
#  [  81  495]]
#
#  F1- Score:  0.39
#
#               precision    recall  f1-score   support
#
#        False       0.95      0.54      0.69      3123
#         True       0.25      0.86      0.39       576
#
#     accuracy                           0.59      3699
#    macro avg       0.60      0.70      0.54      3699
# weighted avg       0.84      0.59      0.64      3699

# %% [markdown]
# ### 5.2.4 K Nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_us = KNeighborsClassifier(n_neighbors=44)
knn_us.fit(X_train_knn_us, y_train_knn_us)

y_test_predict_knn_us = knn.predict(X_test)

# Confusion Matrix
cm_knn_us = confusion_matrix(y_test, y_test_predict_knn_us)
print(cm_knn_us)

print("\n F1- Score: ", round(metrics.f1_score(y_test, y_test_predict_knn_us), 2))

# Various metric scores for KNN
print(classification_report(y_test, y_test_predict_knn_us))
# Out:
# /Users/deepankkartikey/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# [[3052   71]
#  [ 381  195]]
#
#  F1- Score:  0.46
#               precision    recall  f1-score   support
#
#        False       0.89      0.98      0.93      3123
#         True       0.73      0.34      0.46       576
#
#     accuracy                           0.88      3699
#    macro avg       0.81      0.66      0.70      3699
# weighted avg       0.86      0.88      0.86      3699

# %% [markdown]
# ### 5.2.5 Plotting ROC curves for Undersampling majority class

# %%
canvas = plot_roc_curve(dtc_us, X_test, y_test)
plot_roc_curve(rfc_os, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(svm_os, X_test, y_test, ax=canvas.ax_);
plot_roc_curve(knn_os, X_test, y_test, ax=canvas.ax_);
